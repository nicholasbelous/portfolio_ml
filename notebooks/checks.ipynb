# %%
import pandas as pd

f = pd.read_csv("/Users/nick/nick_vscode/portfolio_ml/data/features.csv", index_col=[0,1], parse_dates=[0])

print(f.head())
print(f.describe())
# Out:
#                     mom_1m    mom_3m   vol_20d
# Date
# 2018-04-04 AAPL  -0.029367  0.000292  0.017504
#            MSFT  -0.013972  0.079295  0.026690
#            AMZN  -0.074192  0.186350  0.024153
#            GOOGL -0.059419 -0.040740  0.021891
#            META  -0.140244 -0.145078  0.025731
#              mom_1m        mom_3m       vol_20d
# count  28920.000000  28920.000000  28920.000000
# mean       0.016838      0.048330      0.018236
# std        0.095887      0.173266      0.011594
# min       -0.579195     -0.614406      0.003527
# 25%       -0.032180     -0.041739      0.010744
# 50%        0.016022      0.036605      0.015150
# 75%        0.060606      0.117649      0.021497
# max        1.087097      1.857437      0.107568

# %%
import pandas as pd

X = pd.read_csv("/Users/nick/nick_vscode/portfolio_ml/data/features.csv", index_col=[0,1], parse_dates=[0])
y = pd.read_csv("/Users/nick/nick_vscode/portfolio_ml/data/labels.csv", index_col=[0,1], parse_dates=[0])

print(X.loc[y.index].index.equals(y.index))
# Out:
# True
